# %% [markdown]
# # Universal Eur-Lex parser

# %%
import sys
from pathlib import Path

# Go up two levels: sandbox → ingestion → crss
project_root = Path.cwd().parents[1]
sys.path.append(str(project_root))

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

def fetch_ai_act_robust(celex_id="32024R1689"):
    endpoint_url = "https://publications.europa.eu/webapi/rdf/sparql"

    # We are looking for 'fragments' or 'subdivisions'
    # and the specific 'type' of the legal link (e.g. modification, citation)
    query = f"""
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
    PREFIX eli: <http://data.europa.eu/eli/ontology#>

    SELECT DISTINCT ?link_type ?target_celex ?specific_article WHERE {{
        # ?work cdm:resource_legal_id_celex "{celex_id}"^^<http://www.w3.org/2001/XMLSchema#string> .

        # Look for legal links that have a specific 'note' or 'subtype'
        # ?work cdm:work_has_resource-legal_legal-analysis_not-yet-published ?analysis .
        # ?analysis cdm:resource-legal_legal-analysis_links_resource-legal ?target_work .
        # ?analysis cdm:resource-legal_legal-analysis_type_of_link_resource-legal ?link_type_uri .

        # ?target_work cdm:resource_legal_id_celex ?target_celex .

        # Try to find the fragment/article if it's explicitly tagged in the link
        OPTIONAL {{ ?analysis cdm:resource-legal_legal-analysis_comment_on_legal_link ?specific_article . }}

        BIND(STRAFTER(STR(?link_type_uri), "#") AS ?link_type)
    }} LIMIT 100
    """

    sparql = SPARQLWrapper(endpoint_url)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)

    try:
        results = sparql.query().convert()
        print(f"--- Data found for {celex_id} ---")

        found = False
        for result in results["results"]["bindings"]:
            found = True
            predicate = result["p"]["value"].split("#")[-1] # Simplifies the URL to a name
            target = result.get("target_celex", {}).get("value", "N/A")

            if target != "N/A":
                print(f"Relation: {predicate} --> {target}")

        if not found:
            print("No data found. The CELEX ID might not be indexed in the RDF store yet.")

    except Exception as e:
        print(f"Error: {e}")

fetch_ai_act_robust()
# Out:
# --- Data found for 32024R1689 ---
# Relation: resource_legal_amends_resource_legal --> 32014R0090
# Relation: work_cites_work --> 32002F0584
# Relation: work_cites_work --> 32014L0031
# Relation: work_cites_work --> 32005L0029
# Relation: work_cites_work --> 31985L0374
# Relation: work_cites_work --> 32011R0182
# Relation: work_cites_work --> 32016Q0512(01)
# Relation: work_cites_work --> 32009R0810
# Relation: work_cites_work --> 32013L0036
# Relation: work_cites_work --> 12016P/TXT
# Relation: work_cites_work --> 32002L0058
# Relation: resource_legal_based_on_resource_legal --> 12016E114
# Relation: work_cites_work --> 32013R1024
# Relation: work_cites_work --> 32008L0048
# Relation: work_cites_work --> 32013L0032
# Relation: resource_legal_amends_resource_legal --> 32008R0300
# Relation: work_cites_work --> 12016E/TXT
# Relation: work_cites_work --> 32008D0768
# Relation: work_cites_work --> 12016M004
# Relation: work_cites_work --> 32012R1025
# ...
